# %%
import pandas as pd
import numpy as np
data = pd.read_csv('titanic.csv')

# %%
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})
#data.dtypes

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055513
# sibsp     0.027825
# parch     0.082660
# fare      0.244265

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055513
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# relatives  0.201719

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
### Test the model

from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %%
# Alternatively use Neural Network

from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

# %%
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 30
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 3s 32ms/step - loss: 0.6927 - accuracy: 0.5766
# Epoch 2/50
# 27/27 [==============================] - 0s 17ms/step - loss: 0.6898 - accuracy: 0.5874
# Epoch 3/50
# 27/27 [==============================] - 1s 18ms/step - loss: 0.6838 - accuracy: 0.5981
# Epoch 4/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.6727 - accuracy: 0.5953
# Epoch 5/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.6546 - accuracy: 0.5921
# Epoch 6/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.6352 - accuracy: 0.6322
# Epoch 7/50
# 27/27 [==============================] - 1s 27ms/step - loss: 0.6091 - accuracy: 0.7389
# Epoch 8/50
# 27/27 [==============================] - 0s 15ms/step - loss: 0.5860 - accuracy: 0.7648
# Epoch 9/50
# 27/27 [==============================] - 0s 15ms/step - loss: 0.5480 - accuracy: 0.7910
# Epoch 10/50
# 27/27 [==============================] - 0s 13ms/step - loss: 0.5415 - accuracy: 0.7759
# Epoch 11/50
# 27/27 [==============================] - 1s 37ms/step - loss: 0.5437 - accuracy: 0.7558
# Epoch 12/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.5202 - accuracy: 0.7826
# Epoch 13/50
# 27/27 [==============================] - 0s 19ms/step - loss: 0.5095 - accuracy: 0.7791
# Epoch 14/50
# 27/27 [==============================] - 4s 170ms/step - loss: 0.5075 - accuracy: 0.7804
# Epoch 15/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4741 - accuracy: 0.8011
# Epoch 16/50
# 27/27 [==============================] - 2s 70ms/step - loss: 0.4906 - accuracy: 0.7890
# Epoch 17/50
# 27/27 [==============================] - 0s 16ms/step - loss: 0.4822 - accuracy: 0.7698
# Epoch 18/50
# 27/27 [==============================] - 1s 41ms/step - loss: 0.4669 - accuracy: 0.7931
# Epoch 19/50
# 27/27 [==============================] - 0s 14ms/step - loss: 0.4785 - accuracy: 0.7752
# Epoch 20/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.4879 - accuracy: 0.7679
# Epoch 21/50
# 27/27 [==============================] - 0s 14ms/step - loss: 0.4785 - accuracy: 0.7848
# Epoch 22/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.4773 - accuracy: 0.7784
# Epoch 23/50
# 27/27 [==============================] - 2s 75ms/step - loss: 0.4741 - accuracy: 0.7786
# Epoch 24/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4510 - accuracy: 0.8006
# Epoch 25/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.4478 - accuracy: 0.7999
# Epoch 26/50
# 27/27 [==============================] - 0s 16ms/step - loss: 0.4719 - accuracy: 0.7752
# Epoch 27/50
# 27/27 [==============================] - 3s 100ms/step - loss: 0.4630 - accuracy: 0.7723
# Epoch 28/50
# 27/27 [==============================] - 5s 199ms/step - loss: 0.4403 - accuracy: 0.7999
# Epoch 29/50
# 27/27 [==============================] - 1s 50ms/step - loss: 0.4462 - accuracy: 0.7980
# Epoch 30/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.4528 - accuracy: 0.7970
# Epoch 31/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.4426 - accuracy: 0.7900
# Epoch 32/50
# 27/27 [==============================] - 0s 15ms/step - loss: 0.4841 - accuracy: 0.7596
# Epoch 33/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.4366 - accuracy: 0.7929
# Epoch 34/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4326 - accuracy: 0.7874
# Epoch 35/50
# 27/27 [==============================] - 1s 39ms/step - loss: 0.4329 - accuracy: 0.7921
# Epoch 36/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4367 - accuracy: 0.7890
# Epoch 37/50
# 27/27 [==============================] - 0s 14ms/step - loss: 0.4407 - accuracy: 0.7990
# Epoch 38/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.4732 - accuracy: 0.7704
# Epoch 39/50
# 27/27 [==============================] - 0s 14ms/step - loss: 0.4610 - accuracy: 0.7737
# Epoch 40/50
# 27/27 [==============================] - 0s 14ms/step - loss: 0.4556 - accuracy: 0.7824
# Epoch 41/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4582 - accuracy: 0.7700
# Epoch 42/50
# 27/27 [==============================] - 0s 15ms/step - loss: 0.4564 - accuracy: 0.7698
# Epoch 43/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4335 - accuracy: 0.7971
# Epoch 44/50
# 27/27 [==============================] - 1s 36ms/step - loss: 0.4574 - accuracy: 0.7728
# Epoch 45/50
# 27/27 [==============================] - 3s 104ms/step - loss: 0.4722 - accuracy: 0.7613
# Epoch 46/50
# 27/27 [==============================] - 0s 16ms/step - loss: 0.4528 - accuracy: 0.7830
# Epoch 47/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4255 - accuracy: 0.7981
# Epoch 48/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.4625 - accuracy: 0.7596
# Epoch 49/50
# 27/27 [==============================] - 0s 14ms/step - loss: 0.4513 - accuracy: 0.7860
# Epoch 50/50
# 27/27 [==============================] - 0s 15ms/step - loss: 0.4473 - accuracy: 0.7787

# %%
#y_pred = model.predict_classes(X_test)
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.7942583732057417
